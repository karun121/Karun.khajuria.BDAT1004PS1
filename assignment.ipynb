# %% [markdown]
# # C# questions

# %% [markdown]
# # Question 1
#
# What data type is each of the following?

# %%
5            = int
5.0          = double
5 > 1        = boolean
'5'          = char
5 * 2        = int
'5' * 2      = string
'5' + '2'    = string
5 / 2        = double
5 % 2        = int
{5, 2, 1}    = int
5 == 3       = boolean
Pi           = float

# %% [markdown]
# # Question 2
# Write (and evaluate) C# expressions that answer these questions:
#
# a. How many letters are there in 'Supercalifragilisticexpialidocious'?
#
# b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
#
# c. Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?
#
# d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

# %%
using System;
using System.Collections.Generic;

namespace ConsoleApp1
{
    class Program
    {
        static void Main(string[] args)
        {
            string name = "Supercalifragilisticexpialidocious";   // First Part
            int name1length = name.Length;
            Console.WriteLine("(a) The nummber of letters are: {0} ",name1length);


            string sub = "ice";                                 // Second Part to find the substring of a major string
            bool b = name.Contains(sub);
            Console.WriteLine("(b) '{0}' is in the string '{1}': {2}",
                            sub,name, b);



            string name2 = "Honorificabilitudinitatibus";            // Third part:-  converted the strings into int length and then apply conditionals to find the longest
            string name3 = "Bababadalgharaghtakamminarronnkonn";
            int name2length = name2.Length;
            int name3length = name3.Length;

            if (name1length > name2length && name1length>name3length)
            {
                Console.WriteLine("Supercalifragilisticexpialidocious is the longest");
            }
            else if (name2length > name1length && name2length>name3length)
            {
                Console.WriteLine("Honorificabilitudinitatibus is the longest");
            }
            else 
            {
                Console.WriteLine("Bababadalgharaghtakamminarronnkonn is the longest");
            }

            var dict = new List<string> {"Berlioz","Borodin","Brian","Bartok","Bellini","Buxtehude","Bernstein"}; // Fourth part

            dict.Sort();
            Console.WriteLine(string.Join(",", dict));
            Console.ReadLine();


        }
    }
}

# %% [markdown]
# ![Quest%202%20answer.png](attachment:Quest%202%20answer.png)

# %% [markdown]
# # Question 3
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
# sides of a triangle and returns the area of the triangle. By Heron's formula, the area
# of a triangle with side lengths a, b, and c is
# s(s - a)(s -b)(s -c)
# , where
# s = (a+b+c)/2.

# %%
using System;


namespace Question3
{
    class Program
    {
        static void Main(string[] args)
        {
            float a, b, c;
            a = 2;
            b = 2;
            c = 2;
            Console.Write("Area of the triangle is " + TriangleArea(a, b, c));
            Console.ReadLine();

        }
        static float TriangleArea(float a, float b, float c)
        {
          float  s = (a + b + c) / 2;
            return (float)Math.Sqrt(s * (s - a) * (s - b) * (s - c));
        }

        
    }
}

# %% [markdown]
# ![ques%203.png](attachment:ques%203.png)

# %% [markdown]
# # Question 4
#
# Write a program in C# Sharp to separate odd and even integers in separate arrays.
#
# Go to the editor
# Test Data :
#
# Input the number of elements to be stored in the array :5
#
# Input 5 elements in the array :
#
# element - 0 : 25
#
# element - 1 : 47
#
# element - 2 : 42
#
# element - 3 : 56
#
# element - 4 : 32

# %%
using System;

namespace Quest4
{
    class Program
    {
        static void Main(string[] args)
        {
            int[] array1 = new int[] { 25, 47, 42, 56, 32 };
            int[] array2 = new int[4];
            int[] array3 = new int[4];
            int i, b = 0, c = 0;
            for ( i = 0; i < array1.Length; i++)
            {
                if (array1[i] % 2 == 0)    // for any number to be even, it has to leave a remainder of 0 when divided by 2
                {
                    array2[b] = array1[i];
                    b++;
                }
                else
                {
                    array3[c] = array1[i];
                    c++;
                }
            }
            Console.WriteLine("The Even elements are: ");
            for (i = 0; i < b; i++)
            {
                Console.WriteLine(array2[i]);
            }
            Console.WriteLine("The Odd elements are: ");
            for (i = 0; i < c; i++)
            {
                Console.WriteLine(array3[i]);
            }
            Console.ReadLine();
        }
    }
}

# %% [markdown]
# ![ques4.png](attachment:ques4.png)

# %% [markdown]
# # Question 5
# a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
# depending on whether the point (x,y) lies in the rectangle with lower left
# corner (x1,y1) and upper right corner (x2,y2).
#
# b. Use function inside() from part a. to write an expression that tests whether
# the point (1,1) lies in both of the following rectangles: one with lower left
# corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
# left corner (0.5, 0.2) and upper right corner (1.1, 2).

# %%
using System;

namespace Ques5
{
    class Program
    {
        static void Main(string[] args)
        {
          //  double x = 1, y = 1, x1 = 0, y1 = 0, x2 = 2 , y2 = 3 ;         // part a
         //   double x = 1, y = 1, x1 = 0.3, y1 = 0.5, x2 = 1.1, y2 = 0.7;   // part b
        //   double x = 1, y = 1, x1 = 0.5, y1 = 0.2, x2 = 1.1, y2 = 2;      // part c


            if (Inside(x, y, x1, y1, x2, y2))
                   Console.Write("Yes");
               else
                   Console.Write("No");
                   Console.ReadLine();
        }
        
        static Boolean Inside(double x,double y,double x1,double y1,double x2,double y2)
        {
            if (x > x1 && x < x2 &&           //for a point to be in rectangle it should be greater than (X1,Y1) and less than(X2,Y2) 
                y > y1 && y < y2)
                return true;
            return false;
        }
    }
}

# %% [markdown]
# ![ques5%28a%29.png](attachment:ques5%28a%29.png)

# %% [markdown]
# ![ques5%28b%29.png](attachment:ques5%28b%29.png)

# %% [markdown]
# ![ques5%28c%29.png](attachment:ques5%28c%29.png)

# %% [markdown]
# # PYTHON questions

# %% [markdown]
# # Question 6

# %% [markdown]
# 16. You can turn a word into pig-Latin using the following two rules (simplified):
#
# Write a function pig() that takes a word (i.e., a string) as input and returns its pigLatin form. Your function should still work if the input word contains upper case characters. Your output should always be lower case however.

# %%
def pig(s1):
    s1= s1.lower()
    
    if s1[0] in ("a","e","u","i","o","u"):
        
        s1= s1+'way'
    else:
        s1= s1[1:len(s1):1]+s1[0]+"ay"
    return s1
    
s1=input(str("Enter a word:  "))
latinform= pig(s1)
print("The pig latin form of this word is "+ latinform)
# Out:
# Enter a word:  Enter
# The pig latin form of this word is enterway

# %% [markdown]
# # Question 7
#
# File bloodtype1.txt records blood-types of patients (A, B, AB, O or OO) at a clinic.
# Write a function bldcount() that reads the file with name and reports (i.e.,
# prints) how many patients there are in each bloodtype.

# %%
def bldcount():
 f= open("bloodtype1.txt")

 for line in f:
    count = 0
    count1= 0
    count2= 0
    count3= 0
    count4= 0
    blood= line.split()
    for i in blood:
            if i == 'A':
                count+=1
    print("There are",count,"patients of blood type A")
    
    for line in f:
     
     blood= line.split()
    for i in blood:
           if i =='AB':
               count1+=1
    print("There are",count1,"patients of blood type AB")
    
    for line in f:
    
     blood= line.split()
    for i in blood:
           if i =='O':
               count2+=1
    print("There are",count2,"patients of blood type O")
    for line in f:
     blood= line.split()
    for i in blood:
           if i =='B':
               count3+=1
    print("There is ",count3,"patients of blood  type B")
    for line in f:
     blood= line.split()
    for i in blood:
           if i =='OO':
               count4+=1
    print("There is ",count4,"patients of blood  type OO")
    return ""
    
print(bldcount())
# Out:
# There are 15 patients of blood type A
# There are 13 patients of blood type AB
# There are 15 patients of blood type O
# There is  1 patients of blood  type B
# There is  0 patients of blood  type OO

# %% [markdown]
# # Question 8
#
# Write a function curconv() that takes as input:
# 1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or
# 'EUR' for the Euro)
# 2. an amount
# and then converts and returns the amount in US dollars.
#
#     AUD
#
#     CHF
#
#     CNY
#
#     DKK
#
#     EUR
#
#     GBP
#
#     HKD
#
#     INR
#
#     JPY
#
#     MXN
#
#     MYR
#
#     NOK
#
#     NZD
#
#     PHP
#
#     SEK
#
#     SGD
#
#     THB

# %%
f=open('currencies.txt')
lines = f.readlines()
Dict = {}
for line in lines:
    
 	parsed = line.split("\t")    ## because in txt file all lines are seperated by tab
 	Dict[parsed[0]] = parsed[1]

amount = int(input("Enter amount:\n"))
currency = input("Please enter one of the values given in above question: \n")
currency1=currency.upper()
print(amount,currency1,"is equal to",amount *float(Dict[currency1]),"in USD Dollars")
# Out:
# Enter amount:
# 700
# Please enter one of the values given in above question:
# php
# 700 PHP is equal to 16.32638 in USD Dollars

# %% [markdown]
# # Question 9
# Each of the following will cause an exception (an error). Identify what type of
# exception each will cause.

# %% [markdown]
# # Trying to add incompatible variables, as in adding 6 + ‘a’
#
# "TypeError: unsupported operand type(s) for +: 'int' and 'str'"
#
#
# # Referring to the 12th item of a list that has only 10 items
#
# "IndexError:- It is raised when the index of a sequence is out of range."
#
# # Using a value that is out of range for a function’s input, such as calling math.sqrt(-1.0)
#
#  "ValueError: math domain error"   (Run Time Error)
#
#
# # Using an undeclared variable, such as print(x) when x has not been defined
#
# "NameError: name 'x' is not defined"
#
# # Trying to open a file that does not exist, such as mistyping the file name or looking in the wrong directory.
#
# "FileNotFoundError: [Errno 2] No such file or directory:"

# %% [markdown]
# # Question 10
# Encryption is the process of hiding the meaning of a text by substituting letters in the
# message with other letters, according to some system. If the process is successful, no
# one but the intended recipient can understand the encrypted message. Cryptanalysis
# refers to attempts to undo the encryption, even if some details of the encryption are
# unknown (for example, if an encrypted message has been intercepted). The first step
# of cryptanalysis is often to build up a table of letter frequencies in the encrypted text.
# Assume that the string letters is already defined as
# 'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies()
# that takes a string as its only parameter, and returns a list of integers, showing the
# number of times each character appears in the text. Your function may ignore any
# characters that are not in letters.

# %%
def frequencies(string):
    myDict = {}
    for word in string:
        if word in myDict:
            myDict[word] += 1
        else:
            myDict[word] = 1
    return myDict
    
    
words="The quick red fox got bored and went home"  // part (a)
z= frequencies(words)
print(z)


words2="apple"                                    // part(b)
y= frequencies(words2)
print(y)
# Out:
# {'T': 1, 'h': 2, 'e': 5, ' ': 8, 'q': 1, 'u': 1, 'i': 1, 'c': 1, 'k': 1, 'r': 2, 'd': 3, 'f': 1, 'o': 4, 'x': 1, 'g': 1, 't': 2, 'b': 1, 'a': 1, 'n': 2, 'w': 1, 'm': 1}
# {'a': 1, 'p': 2, 'l': 1, 'e': 1}
